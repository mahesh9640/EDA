# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('laptop_data.csv')
df
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
df.shape
# Out:
# (1303, 12)

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0            int64
# Company              object
# TypeName             object
# Inches              float64
# ScreenResolution     object
# Cpu                  object
# Ram                  object
# Memory               object
# Gpu                  object
# OpSys                object
# Weight               object
# Price               float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df.describe(include='all')
# Out:
#         Unnamed: 0 Company  TypeName       Inches   ScreenResolution  \
# count   1303.00000    1303      1303  1303.000000               1303
# unique         NaN      19         6          NaN                 40
# top            NaN    Dell  Notebook          NaN  Full HD 1920x1080
# freq           NaN     297       727          NaN                507
# mean     651.00000     NaN       NaN    15.017191                NaN
# std      376.28801     NaN       NaN     1.426304                NaN
# min        0.00000     NaN       NaN    10.100000                NaN
# 25%      325.50000     NaN       NaN    14.000000                NaN
# 50%      651.00000     NaN       NaN    15.600000                NaN
# 75%      976.50000     NaN       NaN    15.600000                NaN
# max     1302.00000     NaN       NaN    18.400000                NaN
#
#                                Cpu   Ram     Memory                    Gpu  \
# ...

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# ### Univariate Analysis

# %%
num_cols = df.select_dtypes(include=['int64', 'float64']).columns

for col in num_cols:
    plt.figure(figsize=(8,4))
    sns.histplot(df[col], kde=True)
    plt.title(f'Distribution of {col}')
    plt.show()
    
    print(f"\nStatistics for {col}:")
    print(df[col].describe())
# Out:
# Statistics for Unnamed: 0:
# count    1303.00000
# mean      651.00000
# std       376.28801
# min         0.00000
# 25%       325.50000
# 50%       651.00000
# 75%       976.50000
# max      1302.00000
# Name: Unnamed: 0, dtype: float64
# Statistics for Inches:
# count    1303.000000
# mean       15.017191
# std         1.426304
# min        10.100000
# 25%        14.000000
# 50%        15.600000
# 75%        15.600000
# max        18.400000
# Name: Inches, dtype: float64
# Statistics for Price:
# count      1303.000000
# mean      59870.042910
# std       37243.201786
# min        9270.720000
# 25%       31914.720000
# 50%       52054.560000
# 75%       79274.246400
# max      324954.720000
# Name: Price, dtype: float64

# %% [markdown]
# ### Categorical Features

# %%
cat_cols = df.select_dtypes(include=['object', 'category']).columns

for col in cat_cols:
    plt.figure(figsize=(8,4))
    if len(df[col].unique()) > 10:
        # For high cardinality, show top 10
        df[col].value_counts().nlargest(10).plot(kind='bar')
    else:
        df[col].value_counts().plot(kind='bar')
    plt.title(f'Distribution of {col}')
    plt.xticks(rotation=45)
    plt.show()
    
    print(f"\nValue counts for {col}:")
    print(df[col].value_counts())
# Out:
# Value counts for Company:
# Company
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# Fujitsu        3
# LG             3
# Huawei         2
# Name: count, dtype: int64
# Value counts for TypeName:
# TypeName
# Notebook              727
# Gaming                205
# Ultrabook             196
# 2 in 1 Convertible    121
# Workstation            29
# Netbook                25
# Name: count, dtype: int64
# Value counts for ScreenResolution:
# ScreenResolution
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# ...

# %% [markdown]
# ### 4. Bivariate Analysis

# %% [markdown]
# ### Numerical vs Numerical

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df[num_cols].corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# Pairplot for key numerical features (sample 3-4 important ones)
sns.pairplot(df[num_cols[:4]])  # Adjust based on your columns
plt.show()

# %% [markdown]
# ### Categorical vs Numerical

# %%
for cat_col in cat_cols[:5]:  # Analyze first 5 categorical columns
    for num_col in num_cols[:3]:  # Against first 3 numerical columns
        plt.figure(figsize=(10,6))
        if len(df[cat_col].unique()) > 5:
            # For many categories, show boxplot of top 5
            top_categories = df[cat_col].value_counts().nlargest(5).index
            filtered_df = df[df[cat_col].isin(top_categories)]
            sns.boxplot(x=cat_col, y=num_col, data=filtered_df)
        else:
            sns.boxplot(x=cat_col, y=num_col, data=df)
        plt.title(f'{num_col} by {cat_col}')
        plt.xticks(rotation=45)
        plt.show()

# %% [markdown]
# ### 5. Multivariate Analysis

# %%
# Example: Price distribution by two categorical variables
if 'price' in df.columns and len(cat_cols) >= 2:
    plt.figure(figsize=(12,6))
    sns.barplot(x=cat_cols[0], y='price', hue=cat_cols[1], 
                data=df, estimator='median', ci=None)
    plt.title(f'Price by {cat_cols[0]} and {cat_cols[1]}')
    plt.xticks(rotation=45)
    plt.show()
