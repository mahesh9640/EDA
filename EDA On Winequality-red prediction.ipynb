# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats
df=pd.read_csv("winequality-red.csv", delimiter=';')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.shape
# Out:
# (1599, 12)

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %% [markdown]
# ### Ploting Histograms for all features

# %%
plt.figure(figsize=(20,15))
for i,column in enumerate(df.columns):
    plt.subplot(4,3,i+1)
    sns.histplot(df[column],kde=True,bins=30,color='skyblue')
    plt.title("Distribution of {column}")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Correlation Heatmap

# %%
plt.figure(figsize=(12,10))
corr=df.corr()
sns.heatmap(corr,annot=True,cmap='coolwarm',fmt='.2f',square=True)
plt.title("correlation Heatmap")
plt.show()

# %% [markdown]
# ### Boxplots of key features vs quality

# %%
features=['alcohol']
plt.figure(figsize=(20,12))
for i, feature in enumerate(features):
    plt.subplot(2,3,i+1)
    sns.boxplot(x='quality',y=feature,data=df,palette="Set3")
    plt.title(f'{feature} vs Quality')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\mahesh sai\AppData\Local\Temp\ipykernel_32728\641636560.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='quality',y=feature,data=df,palette="Set3")

# %%
features=['volatile acidity']
plt.figure(figsize=(20,12))
for i, feature in enumerate(features):
    plt.subplot(2,3,i+1)
    sns.boxplot(x='quality',y=feature,data=df,palette="Set3")
    plt.title(f'{feature} vs Quality')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\mahesh sai\AppData\Local\Temp\ipykernel_32728\3369659298.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='quality',y=feature,data=df,palette="Set3")

# %%
features=['citric acid']
plt.figure(figsize=(20,12))
for i,feature in enumerate(features):
    plt.subplot(2,3,i+1)
    sns.boxplot(x='quality',y=feature,data=df,palette='Set3')
    plt.title(f'{feature} vs Quality')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\mahesh sai\AppData\Local\Temp\ipykernel_32728\1773045914.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='quality',y=feature,data=df,palette='Set3')

# %%
features=['residual sugar']
plt.figure(figsize=(20,10))
for i,feature in enumerate(features):
    plt.subplot(2,3,i+1)
    sns.boxplot(x='quality',y=feature,data=df,palette='Set3')
    plt.title(f'{feature} vs Quality')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\mahesh sai\AppData\Local\Temp\ipykernel_32728\1332998830.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='quality',y=feature,data=df,palette='Set3')

# %%
features=['sulphates']
plt.figure(figsize=(20,10))
for i,feature in enumerate(features):
    plt.subplot(2,3,i+1)
    sns.boxplot(x='quality',y=feature,data=df,palette='Set3')
    plt.title(f'{feature} vs Quality')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\mahesh sai\AppData\Local\Temp\ipykernel_32728\3176531400.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='quality',y=feature,data=df,palette='Set3')

# %%
features=['density']
plt.figure(figsize=(20,10))
for i,feature in enumerate(features):
    plt.subplot(2,3,i+1)
    sns.boxplot(x='quality',y=feature,data=df,palette='Set3')
    plt.title(f'{feature} vs Quality')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\mahesh sai\AppData\Local\Temp\ipykernel_32728\804683873.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='quality',y=feature,data=df,palette='Set3')

# %%
import scipy.stats as stats
import matplotlib.pyplot as plt

# List of features to test
features = ['alcohol', 'volatile acidity', 'citric acid', 'residual sugar', 'pH']

# Draw Q-Q plots for each feature
for feature in features:
    plt.figure(figsize=(6, 4))
    stats.probplot(df[feature], dist="norm", plot=plt)
    plt.title(f"Q-Q Plot of {feature}")
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %% [raw]
# ✅ Final EDA Conclusion for – Wine Quality Dataset
# 1. 🧾 Dataset Summary
# Rows: 1,599 wines`
#
# Columns: 12 features (11 numerical + 1 target: quality)
#
# No missing values — dataset is clean and ready for analysis.
#
# 2. 🧠 Target Variable: quality
# The quality column is an ordinal categorical variable with values from 3 to 8.
#
# Most wines are rated 5 or 6.
#
# Very few wines have extreme scores (3 or 8), indicating a balanced, real-world dataset with some class imbalance.
#
# 3. 📊 Feature Distributions (Histograms)
# Features like alcohol, citric acid, sulphates, and volatile acidity show a clear unimodal or skewed distribution.
#
# Residual sugar and total sulfur dioxide show positive skewness, with a few outliers.
#
# Alcohol has a fairly normal-like distribution and stands out as a strong candidate for modeling.
#
# 4. 🔥 Correlation Insights
# Strongest positive correlation with quality:
#
# alcohol (+0.48) — higher alcohol generally leads to better quality.
#
# sulphates and citric acid have moderate positive correlation.
#
# Strongest negative correlation:
#
# volatile acidity (−0.39) — higher acidity tends to lower quality.
#
# density and chlorides also negatively impact quality but weakly.
#
# 5. 📦 Boxplot Analysis: Feature vs. Quality
# Alcohol increases with wine quality — it is a strong differentiator.
#
# Volatile Acidity decreases as quality increases — likely an important inverse predictor.
#
# Citric Acid and Sulphates show increasing trends with higher quality levels.
#
# Residual Sugar and Density have little variation across quality levels — may be less important for predicting quality.
#
# 6. 🧼 Data Quality & Readiness
# No missing or malformed values.
#
# No categorical features — no need for label encoding.
#
# Some features may benefit from scaling (especially for algorithms sensitive to feature range like SVM, KNN).
#
# Optional: Remove or transform outliers if performance issues arise.
#
# ✅ EDA Final Verdict
# The dataset is:
#
# Clean
#
# Well-structured
#
# Ready for model development
