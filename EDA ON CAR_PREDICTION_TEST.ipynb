# %%
import numpy as np
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
import scipy.stats as stats
df1=pd.read_csv('car.csv')
df1
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
df1.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %% [raw]
# # Display basic information
# print("Dataset Shape:", df.shape)
# print("\nFirst 5 Rows:")
# print(df.head())
# print("\nData Types:")
# print(df.dtypes)
# print("\nMissing Values:")
# print(df.isnull().sum())
# print("\nDescriptive Statistics:")
# print(df.describe(include='all'))

# %%
df1.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df1.dtypes
# Out:
# Car_Name          object
# Year               int64
# Selling_Price    float64
# Present_Price    float64
# Kms_Driven         int64
# Fuel_Type         object
# Seller_Type       object
# Transmission      object
# Owner              int64
# dtype: object

# %%
df1.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df1.describe(include='all')
# Out:
#        Car_Name         Year  Selling_Price  Present_Price     Kms_Driven  \
# count       301   301.000000     301.000000     301.000000     301.000000
# unique       98          NaN            NaN            NaN            NaN
# top        city          NaN            NaN            NaN            NaN
# freq         26          NaN            NaN            NaN            NaN
# mean        NaN  2013.627907       4.661296       7.628472   36947.205980
# std         NaN     2.891554       5.082812       8.644115   38886.883882
# min         NaN  2003.000000       0.100000       0.320000     500.000000
# 25%         NaN  2012.000000       0.900000       1.200000   15000.000000
# 50%         NaN  2014.000000       3.600000       6.400000   32000.000000
# 75%         NaN  2016.000000       6.000000       9.900000   48767.000000
# max         NaN  2018.000000      35.000000      92.600000  500000.000000
#
#        Fuel_Type Seller_Type Transmission       Owner
# ...

# %%
### Numerical variables distribution
numerical_columns=['Year','Selling_Price','Present_Price','Kms_Driven','Owner']
plt.figure(figsize=(15,10))
for i, col in enumerate(numerical_columns):
    plt.subplot(2,3,i+1)
    sns.histplot(df1[col],kde=True)
    plt.title(f'Distribution of {col}')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Categorical Variables Distribution
# categorical_columns=['Fuel_Type','Seller_Type','Transmission']
# plt.figure(figsize=(15,5))
# for i, col in enumerate(categorical_columns):
#     plt.subplot(1,3,i+1)
#     df1[col].value_counts().plot(kind='bar')
#     plt.title(f'Distribution of {col}')
#     plt.xticks(rotation=45)
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ### Bivariate analysis:

# %%
### Selling price vs numerical variables
plt.figure(figsize=(15,10))
for i, col in enumerate(['Present_Price','Kms_Driven','Year']):
    plt.subplot(2, 2, i+1)
    sns.scatterplot(x=col, y='Selling_Price', data=df1)
    plt.title(f'Selling Price vs {col}')
plt.tight_layout()
plt.show()

# %%
### Selling price vs numerical values
plt.figure(figsize=(15,5))
for i, col in enumerate(categorical_columns):
    plt.subplot(1,3,i+1)
    sns.boxplot(x=col,y='Selling_Price',data=df1)
    plt.title(f'Selling Price by {col}')
    plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,5))
for i, col in enumerate(['Selling_Price']):
    plt.subplot(2, 2, i+1)
    sns.boxplot(x=df1[col])
    plt.title(f'Boxplot of {col}')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,5))
for i, col in enumerate(['Present_Price']):
    plt.subplot(2,2,i+1)
    sns.boxplot(x=df1[col])
    plt.title(f'Boxplot of {col}')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,5))
for i, col in enumerate(['Kms_Driven']):
    plt.subplot(2,2,i+1)
    sns.boxplot(x=df1[col])
    plt.title(f'Boxplot of {col}')
plt.tight_layout()
plt.show()

# %%
### Q-Q Plots for Numerical Variables
plt.figure(figsize=(4,3))
stats.probplot(df1['Selling_Price'], dist="norm", plot=plt)
plt.title('Q-Q Plot for Selling Price')
plt.show()

# %%
plt.figure(figsize=(4, 3))
stats.probplot(df1['Present_Price'], dist="norm", plot=plt)
plt.title('Q-Q Plot for Present_Price')
plt.show()

# %%
plt.figure(figsize=(4,3))
stats.probplot(df1['Kms_Driven'],dist='norm',plot=plt)
plt.title('Q-Q plot for Kms_Driven')
plt.show()

# %%
### Converting the Kms_Driven into Boxcox
### Applying Box-Cox Transformation

kms_driven=df1['Kms_Druven']=+1
kms_driven
# Out:
# 1

# %%
# Add a small constant to handle zero values if any
kms_driven = df1['Kms_Driven'] + 1

# Perform Box-Cox transformation
transformed_data, lambda_value = stats.boxcox(kms_driven)

# Add transformed data to dataframe
df1['Kms_Driven_BoxCox'] = transformed_data

print(f"Optimal lambda value: {lambda_value:.4f}")
# Out:
# Optimal lambda value: 0.2752

# %%
plt.figure(figsize=(12, 5))

# Transformed distribution
plt.subplot(1, 2, 1)
sns.histplot(df['Kms_Driven_BoxCox'], kde=True)
plt.title('Box-Cox Transformed Distribution')

# Transformed Q-Q plot
plt.subplot(1, 2, 2)
stats.probplot(df1['Kms_Driven_BoxCox'], dist="norm", plot=plt)
plt.title('Q-Q Plot of Transformed Kms_Driven')

plt.tight_layout()
plt.show()

# %%
# Boxplots for numerical variables to detect outliers
for col in num_cols:
    plt.figure(figsize=(8,4))
    sns.boxplot(x=df1[col])
    plt.title(f'Boxplot of {col}')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Vehicle_Age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[239], line 4
#       2 for col in num_cols:
#       3     plt.figure(figsize=(8,4))
# ...

# %%
# Calculate correlation matrix
corr_matrix = df1[['Year', 'Selling_Price', 'Present_Price', 'Kms_Driven', 'Owner']].corr()

# Visualize with a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('Correlation Matrix of Numerical Variables')
plt.show()

# %%
# Create pair plot for Selling_Price vs Present_Price
sns.pairplot(df1, x_vars=['Present_Price'], y_vars=['Selling_Price'], 
             height=5, aspect=1.2, kind='reg')
plt.title('Selling Price vs Present Price')
plt.show()

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

# Prepare data
X = df1[['Present_Price']]
y = df1['Selling_Price']

# Fit linear regression model
model = LinearRegression()
model.fit(X, y)

# Calculate R-squared
r_squared = model.score(X, y)
print(f"R-squared (coefficient of determination): {r_squared:.4f}")
# Out:
# R-squared (coefficient of determination): 0.7726

# %%
# Year vs Selling_Price
sns.pairplot(df1, x_vars=['Year'], y_vars=['Selling_Price'], 
             height=5, aspect=1.2, kind='reg')
plt.title('Selling Price vs Year')
plt.show()

# Kms_Driven vs Selling_Price
sns.pairplot(df1, x_vars=['Kms_Driven'], y_vars=['Selling_Price'], 
             height=5, aspect=1.2, kind='reg')
plt.title('Selling Price vs Kilometers Driven')
plt.show()
