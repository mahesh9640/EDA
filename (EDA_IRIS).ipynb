# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
df=pd.read_csv("iris.csv")
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['sepal.length', 'sepal.width', 'petal.length', 'petal.width',
#        'variety'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal.length  150 non-null    float64
#  1   sepal.width   150 non-null    float64
#  2   petal.length  150 non-null    float64
#  3   petal.width   150 non-null    float64
#  4   variety       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
sns.histplot(df['petal.length'],kde='True')
# Out:
# <Axes: xlabel='petal.length', ylabel='Count'>

# %%
stats.probplot(df['petal.length'],dist='norm',plot=plt)
plt.show()

# %%
stats.probplot(df['petal.width'],dist='norm',plot=plt)
plt.show()

# %%
stats.probplot(df['sepal.length'],dist='norm',plot=plt)
plt.show()

# %%
stats.probplot(df['sepal.width'],dist='norm',plot=plt)
plt.show()

# %%
sns.kdeplot(data=df[df['variety'] == 'Setosa'], x='sepal.length', cumulative=True, label='Setosa')
# Out:
# <Axes: xlabel='sepal.length', ylabel='Density'>

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# Load the Iris dataset
iris = sns.load_dataset('iris')

# Extract the 'sepal_length' column
sepal_lengths = iris['sepal_length']

# Apply CLT: Take many samples and store the mean of each
sample_means = []

for _ in range(1000):  # Take 1000 samples
    sample = np.random.choice(sepal_lengths, size=30, replace=True)
    sample_means.append(np.mean(sample))

# Plot the distribution of sample means
plt.figure(figsize=(8,5))
plt.hist(sample_means, bins=30, edgecolor='black', color='skyblue')
plt.title("Central Limit Theorem on Sepal Length (Iris Dataset)")
plt.xlabel("Sample Mean of Sepal Length")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# Load the Iris dataset
iris = sns.load_dataset('iris')

# Extract the 'sepal_width' column
sepal_width = iris['sepal_width']

# Apply CLT: Take many samples and store the mean of each
sample_means = []

for _ in range(1000):  # Take 1000 samples
    sample = np.random.choice(sepal_width, size=30, replace=True)
    sample_means.append(np.mean(sample))

# Plot the distribution of sample means
plt.figure(figsize=(8,5))
plt.hist(sample_means, bins=30, edgecolor='black', color='skyblue')
plt.title("Central Limit Theorem on Sepal Length (Iris Dataset)")
plt.xlabel("Sample Mean of Sepal width")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# Load the Iris dataset
iris = sns.load_dataset('iris')

# Extract the 'petal_length' column
petal_lengths = iris['petal_length']

# Apply CLT: Take many samples and store the mean of each
sample_means = []

for _ in range(1000):  # Take 1000 samples
    sample = np.random.choice(petal_lengths, size=30, replace=True)
    sample_means.append(np.mean(sample))

# Plot the distribution of sample means
plt.figure(figsize=(8,5))
plt.hist(sample_means, bins=30, edgecolor='black', color='skyblue')
plt.title("Central Limit Theorem on Sepal Length (Iris Dataset)")
plt.xlabel("Sample Mean of petal Length")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# Load the Iris dataset
iris = sns.load_dataset('iris')

# Extract the 'petal_width' column
petal_width= iris['petal_width']

# Apply CLT: Take many samples and store the mean of each
sample_means = []

for _ in range(1000):  # Take 1000 samples
    sample = np.random.choice(sepal_lengths, size=30, replace=True)
    sample_means.append(np.mean(sample))

# Plot the distribution of sample means
plt.figure(figsize=(8,5))
plt.hist(sample_means, bins=30, edgecolor='black', color='skyblue')
plt.title("Central Limit Theorem on Sepal Length (Iris Dataset)")
plt.xlabel("Sample Mean of petal width")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %% [raw]
# EDA:
# Exploratory data analysis:
# why--->we exploring the data
# --->We dont konw anything about the data and we are still trying to ecplote it undersatanding it by using simple statistics mathematics and plotting tools.
#
# 1.Univeral analysis:
#     --->Performing the analysis on single column
# ex: histogram,kde,distribution,check gaussian or not cdf etc
#
# 2.Bivariate analysis:
#     --->Performing the analysis on two columns different types of plots--->Scatter,plot,correlation.
#
# 3.Multivariate analysis:
#     ---> iris--->

# %% [markdown]
# ### EDA On Habermans cancer surviaval dataset:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
df3=pd.read_csv("haberman.csv")
df3
# Out:
#      30  64   1  1.1
# 0    30  62   3    1
# 1    30  65   0    1
# 2    31  59   2    1
# 3    31  65   4    1
# 4    33  58  10    1
# ..   ..  ..  ..  ...
# 300  75  62   1    1
# 301  76  67   0    1
# 302  77  65   3    1
# 303  78  65   1    2
# 304  83  58   2    2
#
# [305 rows x 4 columns]

# %%
df3.shape
# Out:
# (305, 4)

# %%
df3.columns
# Out:
# Index(['30', '64', '1', '1.1'], dtype='object')

# %%
df3.columns=['Age','Operation_Year','aux_nodes','Survival_status']
df3.columns
# Out:
# Index(['Age', 'Operation_Year', 'aux_nodes', 'Survival_status'], dtype='object')

# %%
df3.head()
# Out:
#    Age  Operation_Year  aux_nodes  Survival_status
# 0   30              62          3                1
# 1   30              65          0                1
# 2   31              59          2                1
# 3   31              65          4                1
# 4   33              58         10                1

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 305 entries, 0 to 304
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Age              305 non-null    int64
#  1   Operation_Year   305 non-null    int64
#  2   aux_nodes        305 non-null    int64
#  3   Survival_status  305 non-null    int64
# dtypes: int64(4)
# memory usage: 9.7 KB

# %%
df3['Survival_status']
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 300    1
# 301    1
# 302    1
# 303    2
# 304    2
# Name: Survival_status, Length: 305, dtype: int64

# %%
## How many patients are survived and how many patients are died
df3['Survival_status'].value_counts()
# Out:
# Survival_status
# 1    224
# 2     81
# Name: count, dtype: int64

# %%
df3.isnull().sum()
# Out:
# Age                0
# Operation_Year     0
# aux_nodes          0
# Survival_status    0
# dtype: int64

# %%
df3.describe()
# Out:
#               Age  Operation_Year   aux_nodes  Survival_status
# count  305.000000      305.000000  305.000000       305.000000
# mean    52.531148       62.849180    4.036066         1.265574
# std     10.744024        3.254078    7.199370         0.442364
# min     30.000000       58.000000    0.000000         1.000000
# 25%     44.000000       60.000000    0.000000         1.000000
# 50%     52.000000       63.000000    1.000000         1.000000
# 75%     61.000000       66.000000    4.000000         2.000000
# max     83.000000       69.000000   52.000000         2.000000

# %%
df3.columns
# Out:
# Index(['Age', 'Operation_Year', 'aux_nodes', 'Survival_status'], dtype='object')

# %%
sns.histplot(df3['Age'],kde=True,color='red')
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
stats.probplot(df3['Age'],dist='norm',plot=plt)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(df3,market='Age',linestyle='none')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load the Haberman dataset
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/haberman/haberman.data"
df = pd.read_csv(url, header=None, names=["age", "operation_year", "aux_nodes", "survival_status"])

# Sort the age column
x = np.sort(df["age"])

# Calculate CDF values
y = np.arange(1, len(x) + 1) / len(x)

# Plot the CDF
plt.figure(figsize=(8, 5))
plt.plot(x, y, marker='.', linestyle='none', color='darkblue')
plt.title("CDF of Age (Haberman Dataset)")
plt.xlabel("Age")
plt.ylabel("CDF")
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/haberman/haberman.data"
df = pd.read_csv(url, header=None, names=["age", "operation_year", "aux_nodes", "survival_status"])

# Draw the box plot
plt.figure(figsize=(6, 5))
plt.boxplot(df["age"], vert=True, patch_artist=True, boxprops=dict(facecolor='lightblue'))
plt.title("Box Plot of Age (Haberman Dataset)")
plt.ylabel("Age")
plt.grid(True)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Load data
#df = "https://archive.ics.uci.edu/ml/machine-learning-databases/haberman/haberman.data"
df3 = pd.read_csv(df3, header=None, names=["age", "operation_year", "aux_nodes", "survival_status"])

# Scatter plot: Age vs Auxiliary Nodes, colored by Survival Status
sns.scatterplot(x="age", y="aux_nodes", hue="survival_status", data=df, palette="coolwarm")
plt.title("Age vs Auxiliary Nodes (Colored by Survival Status)")
plt.xlabel("Age")
plt.ylabel("Auxiliary Nodes")
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 7
#       3 import pandas as pd
#       5 # Load data
#       6 #df = "https://archive.ics.uci.edu/ml/machine-learning-databases/haberman/haberman.data"
# ----> 7 df3 = pd.read_csv(df3, header=None, names=["age", "operation_year", "aux_nodes", "survival_status"])
#       9 # Scatter plot: Age vs Auxiliary Nodes, colored by Survival Status
#      10 sns.scatterplot(x="age", y="aux_nodes", hue="survival_status", data=df, palette="coolwarm")
#
# ...

# %%
df3['aux_nodes']
# Out:
# 0       3
# 1       0
# 2       2
# 3       4
# 4      10
#        ..
# 300     1
# 301     0
# 302     3
# 303     1
# 304     2
# Name: aux_nodes, Length: 305, dtype: int64

# %%
df3.columns
# Out:
# Index(['Age', 'Operation_Year', 'aux_nodes', 'Survival_status'], dtype='object')

# %%
sns.set_style('whitegrid')
sns.parplot(df,hue='Surviaval status')
plt.show()

# %%
df3
